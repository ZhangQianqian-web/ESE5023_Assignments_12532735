# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", message="Glyph 8722 (\\N{MINUS SIGN}) missing from font\\(s\\)")

def load_earthquake_data(file_path):
    """读取地震TSV数据并预处理"""
    df = pd.read_csv(file_path, sep="\t", encoding="utf-8", na_values=["", "NA"], keep_default_na=True)
    df = df.dropna(subset=["Country", "Mag"])
    df["Mag"] = pd.to_numeric(df["Mag"], errors="coerce")
    df["Deaths"] = pd.to_numeric(df["Deaths"], errors="coerce").fillna(0)
    df = df.dropna(subset=["Mag"])
    # 组合日期（仅用于最大地震日期提取）
    df["Mo"] = df["Mo"].apply(lambda x: str(int(x)) if pd.notna(x) and x != "" else "01")
    df["Dy"] = df["Dy"].apply(lambda x: str(int(x)) if pd.notna(x) and x != "" else "01")
    df["Combined_Date"] = (
        df["Year"].astype(str) + "-" +
        df["Mo"].str.zfill(2) + "-" +
        df["Dy"].str.zfill(2)
    )
    return df
Sig_Eqs = load_earthquake_data("earthquakes-2025-11-04_14-42-54_+0800.tsv")
def top10_countries_by_deaths(df):
    """统计各国地震总死亡人数，输出前10名"""
    death_stats = df.groupby("Country")["Deaths"].sum().reset_index()
    top10_deaths = death_stats.sort_values(by="Deaths", ascending=False).head(10)
    top10_deaths["Deaths"] = top10_deaths["Deaths"].astype(int)

    print("1.1 地震死亡人数最多的前10个国家")
    print(f"{'排名':<5} {'国家':<15} {'总死亡人数'}")
    for idx, row in top10_deaths.iterrows():
        print(f"{idx+1:<5} {row['Country']:<15} {row['Deaths']}")
    print()
    return top10_deaths
top10_deaths_result = top10_countries_by_deaths(Sig_Eqs)


# 1.2 全球震级>6.0地震时间序列
def eq_above_6_time_series(df):
    """计算全球每年震级>6.0的地震总数并绘制时间序列图"""
    eq_filtered = df[df["Mag"] > 6.0]
    eq_yearly_count = eq_filtered.groupby("Year")["Mag"].count().reset_index(name="Eq_Count")
    all_years = pd.DataFrame({"Year": range(int(eq_filtered["Year"].min()), int(eq_filtered["Year"].max()) + 1)})
    eq_time_series = all_years.merge(eq_yearly_count, on="Year", how="left").fillna(0)
    eq_time_series["Eq_Count"] = eq_time_series["Eq_Count"].astype(int)

    plt.rcParams["font.sans-serif"] = ["Microsoft YaHei", "DejaVu Sans"]
    plt.rcParams["axes.unicode_minus"] = False
    plt.figure(figsize=(14, 7))
    plt.plot(eq_time_series["Year"], eq_time_series["Eq_Count"], color="#2E86AB", linewidth=1.5, label="年度地震数（震级>6.0）")
    plt.xlabel("年份")
    plt.ylabel("地震总数")
    plt.title("全球每年震级>6.0的地震时间序列")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.ylim(bottom=0)
    plt.show()

    return eq_time_series
eq_6_time_series_result = eq_above_6_time_series(Sig_Eqs)


# 1.3 函数CountEq_LargestEq
def CountEq_LargestEq(df, country):
    country_df = df[df["Country"].str.strip() == country.strip()]
    total_eq = len(country_df)

    if total_eq == 0:
        return total_eq, "无记录"  # 仅返回题目要求的两个结果

    # 提取最大震级对应的日期
    largest_eq = country_df.loc[country_df["Mag"].idxmax()]
    largest_eq_date = largest_eq["Combined_Date"]

    return total_eq, largest_eq_date  # 严格返回两个结果


def country_earthquake_summary(df):
    unique_countries = [c.strip() for c in df["Country"].unique() if pd.notna(c) and c.strip() != ""]
    country_summary = []

    for country in unique_countries:
        total_eq, largest_date = CountEq_LargestEq(df, country)
        country_summary.append({
            "Country": country,
            "Total_Earthquakes": total_eq,
            "Largest_Earthquake_Date": largest_date
        })
    summary_df = pd.DataFrame(country_summary)
    summary_df = summary_df.sort_values(by="Total_Earthquakes", ascending=False)

    print("1.3 各国地震统计（按地震总数降序）")
    print(f"{'国家':<15} {'地震总数':<10} {'最大震级地震日期'}")
    for _, row in summary_df.iterrows():
        print(f"{row['Country']:<15} {row['Total_Earthquakes']:<10} {row['Largest_Earthquake_Date']}")

    return summary_df

country_eq_summary_result = country_earthquake_summary(Sig_Eqs)
# Out:
# 1.1 地震死亡人数最多的前10个国家
# 排名    国家              总死亡人数
# 26    CHINA           2082195
# 134   TURKEY          801154
# 62    IRAN            664598
# 55    HAITI           323484
# 65    ITALY           308891
# 67    JAPAN           232275
# 98    PAKISTAN        143711
# 38    ECUADOR         130485
# 135   TURKMENISTAN    112412
# 11    AZERBAIJAN      89251
# 1.3 各国地震统计（按地震总数降序）
# 国家              地震总数       最大震级地震日期
# CHINA           592        1668.0-07-25
# JAPAN           361        2011.0-03-11
# INDONESIA       340        2004.0-12-26
# IRAN            263        856.0-12-22
# USA             229        1964.0-03-28
# TURKEY          224        1939.0-12-26
# GREECE          181        365.0-07-21
# PERU            157        1716.0-02-06
# CHILE           148        1960.0-05-22
# RUSSIA          148        1952.0-11-04
# MEXICO          144        1787.0-03-28
# PHILIPPINES     142        1897.0-09-21
# ITALY           105        1915.0-01-13
# PAPUA NEW GUINEA 99         1919.0-05-06
# TAIWAN          98         1920.0-06-05
# INDIA           86         1950.0-08-15
# COLOMBIA        68         1826.0-06-18
# NEW ZEALAND     66         1826.0-01-01
# AFGHANISTAN     62         1909.0-07-07
# SOLOMON ISLANDS 62         1977.0-04-21
# ECUADOR         58         1906.0-01-31
# VANUATU         57         1913.0-10-14
# PAKISTAN        44         1945.0-11-27
# ALGERIA         39         1980.0-10-10
# GUATEMALA       37         1942.0-08-06
# ALBANIA         35         1893.0-06-14
# VENEZUELA       30         1530.0-09-01
# COSTA RICA      29         1950.0-10-05
# MYANMAR (BURMA) 29         1912.0-05-23
# ARGENTINA       28         1894.0-10-27
# NEW CALEDONIA   28         1875.0-03-28
# NICARAGUA       28         1898.0-04-29
# TAJIKISTAN      28         1907.0-10-21
# EL SALVADOR     25         1776.0-05-30
# AUSTRALIA       24         1989.0-05-23
# KERMADEC ISLANDS (NEW ZEALAND) 23         1986.0-10-20
# USA TERRITORY   23         1902.0-09-22
# TONGA           21         1919.0-04-30
# SOUTH KOREA     21         1643.0-07-25
# PANAMA          20         1882.0-09-07
# NEPAL           19         1505.0-06-06
# CANADA          17         1949.0-08-22
# FIJI            17         1919.0-01-01
# BANGLADESH      15         1918.0-07-08
# FRANCE          15         1817.0-03-11
# GEORGIA         15         1905.0-10-21
# KYRGYZSTAN      15         1911.0-01-03
# SPAIN           15         881.0-05-26
# AZERBAIJAN      14         1667.0-11-01
# SLOVENIA        14         1511.0-03-26
# SOUTH AFRICA    13         1942.0-11-10
# ROMANIA         13         1977.0-03-04
# CROATIA         12         1667.0-04-06
# UZBEKISTAN      12         1976.0-04-08
# BULGARIA        12         1904.0-04-04
# UKRAINE         12         103.0-01-01
# HAITI           11         1842.0-05-07
# AZORES (PORTUGAL) 11         1968.0-02-28
# TURKMENISTAN    11         1895.0-07-08
# BRAZIL          10         1963.0-11-09
# SERBIA          10         1922.0-03-24
# HONDURAS        10         2025.0-02-08
# BOSNIA-HERZEGOVINA 9          1969.0-10-27
# KAZAKHSTAN      9          1889.0-07-11
# ISRAEL          9          -31.0-09-02
# TANZANIA        8          1910.0-12-13
# SAMOA           8          1917.0-06-26
# PORTUGAL        8          -60.0-01-01
# POLAND          8          2004.0-09-21
# DOMINICAN REPUBLIC 8          1946.0-08-04
# ARMENIA         8          1988.0-12-07
# MACEDONIA       8          1979.0-05-24
# BOLIVIA         8          1994.0-06-09
# ETHIOPIA        8          1906.0-08-25
# CONGO           7          1992.0-09-11
# EGYPT           7          1995.0-11-22
# SOUTH GEORGIA AND THE SOUTH SANDWICH ISLANDS 7          1929.0-06-27
# UK              7          1580.0-04-06
# CUBA            7          2020.0-01-28
# NORTH KOREA     6          1518.0-07-02
# ANTARCTICA      6          1998.0-03-25
# ICELAND         6          1912.0-05-06
# TRINIDAD AND TOBAGO 6          1888.0-01-10
# VIETNAM         6          1935.0-11-01
# ATLANTIC OCEAN  6          1941.0-11-25
# MONGOLIA        6          1905.0-07-09
# RWANDA          5          2015.0-08-07
# JORDAN          5          -2150.0-01-01
# MONTENEGRO      5          1979.0-04-15
# GHANA           5          1862.0-07-10
# HUNGARY         5          1834.0-10-15
# BHUTAN          5          2009.0-09-21
# GUADELOUPE      5          1843.0-02-08
# GERMANY         5          1978.0-09-03
# LEBANON         4          1759.0-11-25
# MALAWI          4          1989.0-03-10
# SOUTH SUDAN     4          1990.0-05-20
# ERITREA         4          1875.0-11-02
# SYRIA           4          1202.0-05-20
# SWITZERLAND     4          1601.0-09-18
# MOROCCO         4          2023.0-09-08
# UGANDA          4          1912.0-07-09
# MOZAMBIQUE      3          2006.0-02-22
# NETHERLANDS     3          1992.0-04-13
# MICRONESIA, FED. STATES OF 3          1911.0-08-16
# THAILAND        3          2014.0-05-05
# INDIAN OCEAN    3          1928.0-03-09
# YEMEN           3          1982.0-12-13
# AUSTRIA         3          1590.0-09-15
# IRAQ            3          1864.0-12-02
# MARTINIQUE      3          1906.0-12-03
# SAUDI ARABIA    3          2009.0-05-19
# MALAYSIA        3          1976.0-07-26
# JAMAICA         3          1899.0-06-14
# CYPRUS          3          1953.0-09-10
# ANTIGUA AND BARBUDA 2          1690.0-04-16
# PACIFIC OCEAN   2          1932.0-11-02
# SOLOMON SEA     2          1895.0-03-06
# TUNISIA         2          1957.0-02-20
# LAOS            2          2007.0-05-16
# OMAN            2          1570.0-01-01
# COTE D'IVOIRE   2          1879.0-02-11
# KENYA           2          1928.0-01-06
# TOGO            1          1788.0-01-01
# FRENCH GUIANA   1          1885.0-08-04
# FRENCH POLYNESIA 1          1848.0-07-12
# NORWAY          1          1819.0-08-31
# SIERRA LEONE    1          1795.0-05-20
# PALAU           1          1914.0-10-23
# CENTRAL AFRICAN REPUBLIC 1          1921.0-09-16
# TASMAN SEA      1          1892.0-01-26
# KIRIBATI        1          1905.0-06-30
# DJIBOUTI        1          1989.0-08-20
# GUINEA          1          1983.0-12-22
# UK TERRITORY    1          1983.0-11-30
# BELGIUM         1          1983.0-11-08
# LIBYA           1          1963.0-02-21
# CAMEROON        1          1945.0-09-12
# GABON           1          1974.0-09-23
# SUDAN           1          1993.0-08-01
# SLOVAKIA        1          2004.0-01-10
# BERING SEA      1          1991.0-02-21
# WALLIS AND FUTUNA (FRENCH TERRITORY) 1          1993.0-03-12
# BURUNDI         1          2004.0-02-24
# CZECH REPUBLIC  1          2008.0-11-22
# MADAGASCAR      1          2017.0-01-11
# ZAMBIA          1          2017.0-02-24
# COMOROS         1          2018.0-05-15

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

df = pd.read_csv('2281305.csv', low_memory=False)
df[['WindDir', 'WindDirQC', 'WindSpdType', 'WindSpd', 'WindSpdQC']] = df['WND'].str.split(',', n=4, expand=True)

# 风速单位转换
df['WindSpd'] = pd.to_numeric(df['WindSpd'], errors='coerce') / 10
df['DATE'] = pd.to_datetime(df['DATE'])

# 筛选2010-2020年数据
df = df[(df['DATE'] >= datetime.datetime(2010, 1, 1)) & (df['DATE'] <= datetime.datetime(2020, 12, 31))]

# 按月聚合计算平均风速
df['YearMonth'] = df['DATE'].dt.to_period('M')
monthly_avg_wind = df.groupby('YearMonth')['WindSpd'].mean().reset_index()
monthly_avg_wind['YearMonth'] = monthly_avg_wind['YearMonth'].dt.to_timestamp()

# 绘制月平均风速趋势图
plt.figure(figsize=(12, 6))
plt.plot(monthly_avg_wind['YearMonth'], monthly_avg_wind['WindSpd'], color='blue', linewidth=1.5)
plt.title('Monthly Averaged Wind Speed in Shenzhen (2010-2020)')
plt.xlabel('Observation Time')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

# 3.1 数据加载与清洗
local_file_path = "co2_mm_mlo.csv"
df = pd.read_csv(
    local_file_path,
    skiprows=40,
    header=0,
    names=["year", "month", "decimal_date", "co2", "deseasonalized", "n_days", "sdev", "uncertainty"]
)
# 处理无效值并删除缺失值
df = df.replace([-9.99, -0.99], np.nan)
df = df.dropna(subset=["co2"])
# 构建日期索引
df["date"] = pd.to_datetime(df[["year", "month"]].assign(day=1))
df = df.set_index("date")

# 3.2 绘制时间序列
plt.figure(figsize=(12, 6))
plt.plot(df.index, df["co2"], color="red", linewidth=1.2, label="月度CO2浓度")
plt.plot(df.index, df["deseasonalized"], color="blue", linewidth=1.5, label="去季节化趋势")
plt.title("CO2浓度变化趋势（1958-2023）")
plt.xlabel("年份")
plt.ylabel("CO2浓度（ppm）")
plt.legend()
plt.grid(linestyle="--", alpha=0.7)
plt.show()

# 3.3 5项统计检验
## 1. 描述性统计
desc_stats = df["co2"].describe().round(2)
print("1. 描述性统计：")
print(desc_stats)

## 2. 近10年平均CO2浓度
df["year"] = df.index.year
annual_mean = df.groupby("year")["co2"].mean().tail(10).round(2)
print("\n2. 近10年平均CO2浓度：")
print(annual_mean)

## 3. 长期趋势（每10年上升幅度）
x = np.arange(len(df))
y = df["co2"].values
slope, _ = np.polyfit(x, y, 1)
print(f"\n3. 长期趋势：每10年CO2浓度上升 {slope*120:.2f} ppm")

## 4. 极值记录
max_co2 = df["co2"].max()
max_date = df[df["co2"] == max_co2].index[0].strftime("%Y-%m")
min_co2 = df["co2"].min()
min_date = df[df["co2"] == min_co2].index[0].strftime("%Y-%m")
print(f"\n4. 极值记录：")
print(f"   最高浓度：{max_co2:.2f} ppm（{max_date}）")
print(f"   最低浓度：{min_co2:.2f} ppm（{min_date}）")

## 5. 各月份平均CO2浓度
df["month"] = df.index.month
monthly_avg = df.groupby("month")["co2"].mean().round(2)
print("\n5. 各月份平均CO2浓度：")
for month, avg in monthly_avg.items():
    print(f"   {month}月：{avg} ppm")
# Out:
# 1. 描述性统计：
# count    810.00
# mean     360.36
# std       32.68
# min      312.42
# 25%      330.80
# 50%      355.79
# 75%      386.32
# max      430.51
# Name: co2, dtype: float64
#
# 2. 近10年平均CO2浓度：
# year
# 2016    404.41
# 2017    406.76
# 2018    408.72
# 2019    411.65
# 2020    414.21
# 2021    416.41
# 2022    418.53
# 2023    421.08
# 2024    424.60
# 2025    428.12
# Name: co2, dtype: float64
#
# 3. 长期趋势：每10年CO2浓度上升 16.55 ppm
#
# 4. 极值记录：
#    最高浓度：430.51 ppm（2025-05）
#    最低浓度：312.42 ppm（1958-10）
#
# 5. 各月份平均CO2浓度：
#    1月：360.57 ppm
#    2月：361.35 ppm
#    3月：361.51 ppm
#    4月：362.81 ppm
#    5月：363.39 ppm
#    6月：362.84 ppm
#    7月：361.3 ppm
#    8月：359.28 ppm
#    9月：356.75 ppm
#    10月：356.81 ppm
#    11月：358.16 ppm
#    12月：359.48 ppm
